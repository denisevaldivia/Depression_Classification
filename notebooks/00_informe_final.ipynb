# %% [markdown]
# ___
# <img style="float: right; margin: 15px 15px 15px 15px;" src="https://img.freepik.com/free-vector/depression-concept-illustration_114360-3747.jpg?t=st=1657678284~exp=1657678884~hmac=b8b1d71ca0a8eb2e4ff5bf31d6a98624112f1a2254b0f39e92254ed12d7875b2" width="240px" height="180px" />
#
# # <font color= #bbc28d> **Clasificación de Depresión - Informe Final** </font>
# #### <font color= #2E9AFE> `Proyecto de Ciencia de Datos`</font>
# - <Strong> Sofía Maldonado, Diana Valdivia, Samantha Sánchez & Vivienne Toledo </Strong>
# - <Strong> Fecha </Strong>: 30/09/2025
#
# ___
#
# <p style="text-align:right;"> Image retrieved from: https://img.freepik.com/free-vector/depression-concept-illustration_114360-3747.jpg?t=st=1657678284~exp=1657678884~hmac=b8b1d71ca0a8eb2e4ff5bf31d6a98624112f1a2254b0f39e92254ed12d7875b2/p>

# %% [markdown]
# ## <font color= #bbc28d>• **Introducción** </font>
# El análisis de datos relacionados con la **salud mental** se ha convertido en un área de creciente interés dentro de la ciencia de datos y de la medicina, debido a su impacto social y a la posibilidad de diseñar herramientas de apoyo a la toma de decisiones. En este proyecto se trabaja con un conjunto de datos que **clasifica a estudiantes** en dos categorías: aquellos que presentan **síntomas de depresión** y **aquellos que no**.
#
# El desarrollo del proyecto implica la aplicación de un trabajo de clasificación que abarca etapas como el preprocesamiento de datos, el análisis exploratorio, la selección de características y la construcción de modelos. Estas fases permiten no solo entrenar y evaluar algoritmos predictivos, sino también comprender mejor la calidad y distribución de los datos, el cual es un aspecto fundamental en la medicina y por ende para desarrollar un proyecto de ciencia de datos que ayude a resolver este problema correctamente.
#
# De esta manera, este proyecto es una **oportunidad para evidenciar** de manera práctica los conceptos revisados en clase, desde la creación de un espacio colaborativo para desarrollar el proyecto hasta la presentación de resultados de modelos de predicción. Además, nos muestra la importancia de aplicar metodologías de trabajo estructuradas cuando se trabaja de manera colaborativa en proyectos de ciencia de datos.

# %% [markdown]
# ## <font color= #bbc28d>• **Antecedentes** </font>
# Según la Organización Mundial de la Salud (OMS), **alrededor del 4,0 % de la población mundial padece depresión**, cifra que asciende al 5,7 % en adultos (4,6 % en hombres y 6,9 % en mujeres) y al 5,9 % en personas de 70 años o más. No resulta sorprendente que la salud mental influya de forma directa en nuestros pensamientos, conductas y acciones; así como también sea determinante en la manera en que interactuamos con los demás, afrontamos las situaciones y tomamos decisiones. En términos generales, **la salud mental tiene un impacto en todos los ámbitos de la vida**, desde las acciones más cotidianas a casos más específicos.
#
# El uso de técnicas de machine learning para la predicción de trastornos de salud mental **no es una idea reciente**, sino que ha sido algo que se ha estado estudiando. Por ejemplo, **Islam et al. (2024)** compararon varios modelos de aprendizaje automático aplicados desde 2018 en diferentes países, evaluando la predicción de depresión, trastorno bipolar y tendencias suicidas. Por otro lado, **Madububambachu, Ukpebor e Ihezue (2024)** exploran cómo el machine learning puede ayudar a predecir problemas de salud mental en estudiantes universitarios, analizando modelos y estudios previos que van desde SVM hasta redes neuronales convolucionales. Asimismo, otro estudio que se dedicó a comparar los diferentes modelos de ML fue el de **Chung and Teo (2022)**, donde los trastornos a los que se enfocan tratan la esquizofrenia, la bipolaridad, la ansiedad y depresión, también comparando diversos casos de estudio y resultados.
#
# Estos ejemplos demuestran que ya se han hecho varios intentos por predecir la salud mental de las personas usando machine learning. Además, nos ayudan a ver qué **técnicas y modelos** han funcionado mejor para distintos trastornos y a entender por qué estos avances podrían ser realmente útiles, no solo para investigadores, sino para cualquiera que quiera mejorar la detección y el cuidado de la salud mental.
#
# Nuestro proyecto busca usar machine learning para predecir de manera más precisa qué **estudiantes muestran síntomas de depresión**, manejando los datos de forma ética y responsable. Con esto, no solo entendemos mejor los factores que influyen en la depresión, sino que también podemos **crear herramientas prácticas** que ayuden a detectar y atender estos casos de forma temprana en las escuelas y universidades.

# %% [markdown]
# ## <font color= #bbc28d>• **Objetivos** </font>
# #### <font color= #99c0c4>• **Particular** </font>
# - Establecer un proceso de ingesta, visualización, transformación, modelado y predicción de datos, a partir del análisis de un dataset sobre la prevalencia de la depresión en estudiantes, con el propósito de construir una metodología sólida, eficiente y adaptable para el desarrollo de proyectos en Ciencia de Datos.
#
# #### <font color= #99c0c4>• **Específicos** </font>
# - Integrar múltiples conocimientos adquiridos a lo largo de nuestra carrera en materia de tratamiento de datos, optimización, machine learning y presentación de resultados, para consolidar una entrega que cumpla con los estándares de calidad de la industria y refleje nuestro aprendizaje como estudiantes.
#
# - Definir la estructura y cadena de producción de un proyecto de Ciencia de Datos, mediante la familiarización con la documentación de un proyecto, investigación de librerías, convenciones comunes y buenas prácticas, con la finalidad de ser capaces de desarrollar proyectos de calidad a futuro en nuestra carrera.
#
# - Categorizar correctamente los datos encontrados mediante el uso de algoritmos de machine learning, para demostrar nuestra capacidad de modelado y el éxito de nuestro proyecto, a través de las métricas adecuadas y representativas de nuestro problema de clasificación.
#
# - Facilitar la detección temprana de la depresión mediante el análisis de un dataset de la prevalencia de depresión en estudiantes, para identificar los factores y señales de riesgo que intersectan a este padecimiento y proponer soluciones o herramientas de prevención.
#
# #### <font color= #99c0c4>• **Criterios de Éxito** </font>
# - Al tratarse de un problema de **clasificación**, existen varias métricas que podríamos aplicar [i.e. Precision, Recall, F1-score, etc]. Sin embargo, al no querer sacrificar la sensibilidad de unos tipos de errores por otros, nos enfocaremos más en la `F1-Score` y la `matriz de confusión` para poder retroalimentar nuestros modelos.
# - Nos gustaría contar con un `F1-Score > 85`.

# %% [markdown]
# ## <font color= #bbc28d>• **Planteamiento del Problema** </font>
# #### <font color= #99c0c4>• **Formulación precisa del problema** </font>
# - ¿Se puede desarrollar un modelo de machine learning que funcione como apoyo para identificar de manera temprana a estudiantes con riesgo de depresión?
#
# #### <font color= #99c0c4>• **Variables clave** </font>
# Dentro de las **variables de entrada**, podemos encontrar dos categorías:
# - `Demográficas` ~ Género, edad, ciudad y profesión.
# - `Factores psicológicos o de estilo de vida` ~ Presión académica o de trabajo, hábitos alimenticios, estrés financiero, etc.
#
# **Variable de salida:** presencia o ausencia de síntomas depresivos.
#
# #### <font color= #99c0c4>• **Impacto esperado** </font>
# Como se mencionó previamente, la **detección temprana de una enfermedad mental** puede traer beneficios significativos, como una mejor calidad de vida, ahorro en el costo de tratamientos, prevenir la cronicidad e incluso el suicido en jóvenes.
# Si nuestro proyecto resulta exitoso, podemos brindar información sobre **qué factores son los más relevantes** en la detección de depresión, para así poder diseñar nuevas estrategias con un enfoque especializado. Además de construir una herramienta que puede ser utilizada en contextos académicos a la par de profesionales para un diagnóstico y tratamiento más efectivo y temprano.
#
# #### <font color= #99c0c4>• **Riesgos conocidos** </font>
# Dentro de los riesgos a los cuáles nos enfrentamos son los **valores faltantes** [que bien no son muchos], **variables** que podrían resultar **irrelevantes** [como la profesión ya que el 97% son estudiantes], un **sesgo geográfico** ya que las ciudades que aparecen son todas de la **India**, lo cual no es una representación fiel de los estudiantes en México [aunque no encontramos un dataset sobre México en específico], el famoso **data leakage** que podría ocurrir en el procesamiento de los datos o al entrenar los modelos y que existan **factores relevantes** para la detección de la depresión **que no se encuentren en el conjunto de datos**. Sin importar los grandes beneficios que puede traer la detección temprana de depresión, esta es una tarea compleja ya que puede implicar **factores genéticos, del entorno en dónde viven o incluso experiencias de la vida**, que es difícil de concentrar y representar en un único conjunto de datos.

# %% [markdown]
# ## <font color= #bbc28d>• **EDA** </font>

# %% [markdown]
# Nuestro dataset cuenta con 17 variables y 1 target, de las cuales 9 son numéricas y 8 categóricas. Nuestra target es binaria, describiendo si la persona tiene depresión [1] o no [0].
#
# #### <font color= #99c0c4>• **Variables Cuantitativas** </font>
#
# La mayoría de nuestros registros provienen de estudiantes o adultos jóvenes. Por lo tanto, gran parte de ellos no tiene trabajo, y reportan valores bajos en `Job Satisfaction` y `Work Pressure`. Sin embargo, sí reportan `altos valores de estrés académico y financiero`, debido a su cualidad de estudiantes.
#
# A primera vista, podemos notar la presencia de valores atípicos en la edad, por lo que sería importante considerarlos para el tratamiento. Además de un desbalance ligero en las clases de predicción que puede ser tratado con la generación de datos sintéticos.
#
# En cuanto a la influencia de cada variable a la presencia de la depresión, los datos sugieren que la `depresión aumenta conforme lo hace el estrés académico y financiero, así como la insatisfacción con los estudios y las horas dedicadas al estudio o trabajo.`
#
# #### <font color= #99c0c4>• **Variables Cualitativas** </font>
#
# Las variables cualitativas comprenden el sexo de les participantes, hábitos alimenticios, de higiene de sueño, ciudad, antecedentes de depresión en su familia y profesión. Analizando estos valores, se descubrió que en los registros, el sexo de las personas no influye demasiado en la prevalencia de la depresión. Sin embargo, `pobres hábitos de alimentación y calidad de sueño incrementan la prevalencia de la depresión.`
#
# Además, las `personas que solo terminaron el bachillerato presentan mayores índices de depresión, así como aquellas con pensamientos suicidas`. Mientras que los antecedentes de enfermedades mentales en la familia de las personas entrevistadas no parece afectar la presencia de depresión.
#
# Por otro lado, existen variables categóricas que no aportan demasiado al análisis (Profession), pues se tratan de estudiantes. Así como ciudad, que quizás no aporte demasiado valor al estudio.

# %% [markdown]
# ## <font color= #bbc28d>• **Limpieza de Datos** </font>

# %% [markdown]
# En esta etapa se siguió trabajando con nuestro archivo archivo depression_dataset.csv, aplicando diferentes transformaciones y limpiezas para preparar los datos antes del modelado. Las acciones principales fueron:
#
# #### <font color= #99c0c4>1. **Tratamiento de datos faltantes** </font>
# - Se detectó que la columna Financial Stress contenía 3 valores nulos.
#
# - Dado que era una cantidad pequeña en comparación con el total de registros, se decidió eliminar esas filas.
#
# #### <font color= #99c0c4>2. **Filtrado de datos categóricos** </font>
# - Se identificaron variables con categorías poco representativas (con una o dos filas por valor), como City, Dietary Habits, Sleep Duration y Profession.
#
# - Se eliminaron registros aislados para evitar problemas de ruido y mejorar la representatividad de los datos.
#
# #### <font color= #99c0c4>3. **Ajuste del dataset al enfoque del proyecto** </font>
# - Dado que el análisis está dirigido a estudiantes, se filtraron los registros de la variable Profession para conservar solo aquellos relacionados con población estudiantil.
#
# #### <font color= #99c0c4>4. **Verificación final** </font>
# - Se comprobó que el dataset resultante no presentara valores faltantes.
#
# - Se aseguró la coherencia de las variables categóricas para proceder con la codificación en fases posteriores.

# %% [markdown]
# ## <font color= #bbc28d>• **Modelado** </font>

# %% [markdown]
# Para realizar la tarea de clasificación, se entrenarán los siguientes modelos:
#
# - Logistic Regression (como baseline)
#
# - Support Vector Classifier
#
# - XGBoost

# %% [markdown]
# Elegimos estos modelos ya que nos permiten observar nuestro piso con el modelo clasificatorio más sencillo que hay. Al mismo tiempo, tenemos dos modelos más robustos que siguen siendo relativamente compactos a diferencia de algo como una red neuronal pero que también nos van a dar un mejor rendimiento.

# %% [markdown]
# ## <font color= #bbc28d>• **Resultados** </font>

# %% [markdown]
# ![title](../assets/resultados_modelos.jpg)

# %% [markdown]
# Hicimos 3 trials, o "runs" para cada uno de los 3 modelos para un total de 9 experimentos.
#
# Sorprendentemente, nuestro modelo *champion* fue el de Regresión Logística. Debido a la sencillez de este modelo, el único hiperparámetro que modificamos entre las runs fue el solver. El *saga* terminó siendo el mejor. Tuvimos un valor de F1-Score máximo de $0.867$
#
# Aparte del modelo de Regresión Logística, el segundo mejor fue el de Support Vector Classifier con una puntuación máxima de $0.861$. Nuestro modelo XGBoost, originalmente pronosticado como el que sería nuestro mejor modelo, se encuentra en 3er lugar con un score máximo de $0.860$.
#
# En realidad estos 3 modelos están bastante cerca en rendimiento, con una diferencia de apenas $0.7$% entre el mejor modelo XGBoost y el mejor modelo de Regresión Logística.
#
# Decidimos usar la **F1-Score** como nuestra métrica objetivo ya que combina la *precision* y el *recall* en un solo número. El valor de *precision* es muy importante para nuestro proyecto ya que nos interesa poder encontrar a todos los alumnos que SI sufren de depresión, para que puedan recibir la ayuda que necesitan.

# %% [markdown]
# ## <font color= #bbc28d>• **Conclusiones (1era Entrega)** </font>

# %% [markdown]
# #### <p style="color: #99c0c4">**Avance de Entrega** </p>
# En esta primer entrega ya se hizo una exploración de una problemática que afecta a todo el mundo, y decidimos un dataset que nos va a permitir hacer un estudio de esta situación, al menos con estudiantes en un contexto específico (India).
#
# Hicimos una exploración completa de los datos, encontrando patrones y observando como sus diferentes características interactúan entre si y con la variable de objetivo o target. Gracias a este proceso encontramos características como `Profession` que no daban información y que podemos ir descartando, optimizando el proceso de crear los modelos inmediatamente.
#
# En la limpieza de datos pudimos eliminar valores nulos y registros aislados o atípicos que iban a dificultar la tarea de los modelos a la hora de entrenarse.
#
# También se hizo la tarea de codificar las variables categóricas. Las binarias se codificaron con 0 y 1, mientras que para las otras se utilizó un One-Hot Encoding.
# #### <p style="color: #99c0c4">**Roadmap Inmediato** </p>
# Nuestro roadmap actual se enfoca en poder empezar el modelado de los datos. El trabajo como la codificación de variables categóricas y la separación de datos de entrenamiento y prueba ya se hizo.
#
# Nuestras principales métricas donde quisiéramos obtener una puntuación alta son `Accuracy`, `Recall` y por asociación `F1 Score`, ya que se construye de las dos métricas previas. Accuracy es relevante porque nos dice cuántas de nuestras predicciones son correctas, y Recall es muy importante debido a que, en este caso, predecir que una persona **NO** sufre de depresión cuando este **SI** es el caso podría evitar que acceda a la atención de salud mental que urgentemente requiere. Para este proyecto, **evitar falsos negativos es más importante que evitar falsos positivos**.
#
# #### <p style="color: #99c0c4">**Limitaciones Vigentes**</p>
#
# Actualmente no sentimos que estemos limitadas para completar nuestro roadmap. Como se mencionó arriba, puede que la variable de `City` resulte ser un obstáculo que no nos dé mucha información relevante a la hora de construir los modelos, pero esto no lo sabremos hasta ya empezar el modelado.
#
# No encontramos ningún obstáculo mayor en el trabajo de exploración, limpieza y pre-procesamiento de los datos y todo parece indicar que podremos entrenar modelos sólidos de clasificación que nos den insights sobre las variables más relevantes para predecir la depresión.

# %% [markdown]
# ## <font color= #bbc28d>• **Referencias** </font>
# **Papers Científicos**
# - Islam, M. M., Hassan, S., Akter, S., Jibon, F. A., & Sahidullah, M. (2024). A comprehensive review of predictive analytics models for mental illness using machine learning algorithms. Healthcare Analytics, 6, 100350. https://doi.org/10.1016/j.health.2024.100350
# - Madububambachu, U., Ukpebor, A., & Ihezue, U. (2024). Machine Learning Techniques to Predict Mental Health Diagnoses: A Systematic Literature Review. Clinical Practice and Epidemiology in Mental Health, 20(1). https://doi.org/10.2174/0117450179315688240607052117
# - Chung, J., & Teo, J. (2022). Mental health prediction using Machine Learning: Taxonomy, applications, and challenges. Applied Computational Intelligence and Soft Computing, 2022, 1–19. https://doi.org/10.1155/2022/9970363
#
# **Páginas Web**
# - World Health Organization: WHO & World Health Organization: WHO. (2025, August 29). Trastorno depresivo (depresión). https://www.who.int/es/news-room/fact-sheets/detail/depression
#
# **Dataset**
# - Opeyemi, S. (2024, noviembre 22). *Student Depresion Dataset*. Kaggle. https://www.kaggle.com/datasets/hopesb/student-depression-dataset
